# %%
[
{
"question": "If 3x + 9 = 18, what is x?",
"options": ["1", "2", "3", "4"],
"correct_answer": "3",
"difficulty": 0.2,
"topic": "Algebra",
"tags": ["linear equations"]
},
{
"question": "What is the value of 5^2?",
"options": ["10", "20", "25", "30"],
"correct_answer": "25",
"difficulty": 0.1,
"topic": "Arithmetic",
"tags": ["exponents"]
},
{
"question": "The synonym of 'Aberration' is:",
"options": ["Deviation", "Normality", "Harmony", "Balance"],
"correct_answer": "Deviation",
"difficulty": 0.5,
"topic": "Vocabulary",
"tags": ["synonyms"]
},
{
"question": "If a triangle has sides 3,4,5 then it is:",
"options": ["Equilateral", "Isosceles", "Right triangle", "Obtuse triangle"],
"correct_answer": "Right triangle",
"difficulty": 0.4,
"topic": "Geometry",
"tags": ["triangles"]
},
{
"question": "What is 20% of 150?",
"options": ["20", "25", "30", "35"],
"correct_answer": "30",
"difficulty": 0.2,
"topic": "Arithmetic",
"tags": ["percentage"]
},
{
"question": "Solve: 2x = 16",
"options": ["6", "7", "8", "9"],
"correct_answer": "8",
"difficulty": 0.2,
"topic": "Algebra",
"tags": ["linear equations"]
},
{
"question": "Perimeter of square with side 5?",
"options": ["10", "15", "20", "25"],
"correct_answer": "20",
"difficulty": 0.2,
"topic": "Geometry",
"tags": ["square"]
},
{
"question": "Antonym of 'Benevolent'?",
"options": ["Kind", "Cruel", "Generous", "Friendly"],
"correct_answer": "Cruel",
"difficulty": 0.6,
"topic": "Vocabulary",
"tags": ["antonyms"]
},
{
"question": "What is √81?",
"options": ["7", "8", "9", "10"],
"correct_answer": "9",
"difficulty": 0.2,
"topic": "Arithmetic",
"tags": ["square root"]
},
{
"question": "If x + 5 = 12, find x",
"options": ["5", "6", "7", "8"],
"correct_answer": "7",
"difficulty": 0.2,
"topic": "Algebra",
"tags": ["linear equations"]
},
{
"question": "Area of rectangle with length 8 and width 5?",
"options": ["30", "35", "40", "45"],
"correct_answer": "40",
"difficulty": 0.3,
"topic": "Geometry",
"tags": ["area"]
},
{
"question": "What is 15% of 200?",
"options": ["20", "25", "30", "35"],
"correct_answer": "30",
"difficulty": 0.3,
"topic": "Arithmetic",
"tags": ["percentage"]
},
{
"question": "Meaning of 'Candid'?",
"options": ["Honest", "Hidden", "False", "Secret"],
"correct_answer": "Honest",
"difficulty": 0.4,
"topic": "Vocabulary",
"tags": ["meaning"]
},
{
"question": "Solve: 4x = 20",
"options": ["4", "5", "6", "7"],
"correct_answer": "5",
"difficulty": 0.3,
"topic": "Algebra",
"tags": ["linear equations"]
},
{
"question": "Area of circle formula?",
"options": ["πr", "πr²", "2πr", "r²"],
"correct_answer": "πr²",
"difficulty": 0.4,
"topic": "Geometry",
"tags": ["circle"]
},
{
"question": "What is 7×8?",
"options": ["54", "56", "58", "60"],
"correct_answer": "56",
"difficulty": 0.1,
"topic": "Arithmetic",
"tags": ["multiplication"]
},
{
"question": "Antonym of 'Scarce'?",
"options": ["Rare", "Plenty", "Limited", "Few"],
"correct_answer": "Plenty",
"difficulty": 0.5,
"topic": "Vocabulary",
"tags": ["antonym"]
},
{
"question": "Solve: x/2 = 6",
"options": ["10", "11", "12", "13"],
"correct_answer": "12",
"difficulty": 0.3,
"topic": "Algebra",
"tags": ["equations"]
},
{
"question": "Sum of angles in triangle?",
"options": ["90", "180", "270", "360"],
"correct_answer": "180",
"difficulty": 0.2,
"topic": "Geometry",
"tags": ["triangle"]
},
{
"question": "What is 9²?",
"options": ["72", "81", "90", "99"],
"correct_answer": "81",
"difficulty": 0.2,
"topic": "Arithmetic",
"tags": ["square"]
},
{
"question": "Meaning of 'Ephemeral'?",
"options": ["Short-lived", "Permanent", "Strong", "Ancient"],
"correct_answer": "Short-lived",
"difficulty": 0.7,
"topic": "Vocabulary",
"tags": ["advanced vocab"]
},
{
"question": "Solve: 6x = 42",
"options": ["6", "7", "8", "9"],
"correct_answer": "7",
"difficulty": 0.3,
"topic": "Algebra",
"tags": ["equation"]
},
{
"question": "Area of triangle = ?",
"options": ["bh", "1/2 bh", "b+h", "bh²"],
"correct_answer": "1/2 bh",
"difficulty": 0.3,
"topic": "Geometry",
"tags": ["area"]
},
{
"question": "What is 100/4?",
"options": ["20", "25", "30", "35"],
"correct_answer": "25",
"difficulty": 0.1,
"topic": "Arithmetic",
"tags": ["division"]
},
{
"question": "Synonym of 'Obsolete'?",
"options": ["Modern", "Outdated", "Fresh", "Recent"],
"correct_answer": "Outdated",
"difficulty": 0.6,
"topic": "Vocabulary",
"tags": ["synonym"]
}
]

# %%
from pymongo import MongoClient

uri = "mongodb+srv://atharva007:atharva007@prepration-evaluator-cl.59zqj5t.mongodb.net/?appName=prepration-evaluator-clustor"

client = MongoClient(uri)

print(client.list_database_names())
# Out:
# ['admin', 'local']

# %%
import json
from pymongo import MongoClient

client = MongoClient(
    "mongodb+srv://atharva007:atharva007@prepration-evaluator-cl.59zqj5t.mongodb.net/?appName=prepration-evaluator-clustor"
)

db = client["gre-question-bank"]

questions_collection = db["gre_questions"]

with open(r"U:\generative_ai_projects\prepration_evaluator\data\gre_questions.json") as f:
    questions = json.load(f)

result = questions_collection.insert_many(questions)

print(f"{len(result.inserted_ids)} questions inserted successfully")
# Out:
# 25 questions inserted successfully

# %%
from pymongo import MongoClient

uri = "mongodb+srv://atharva007:atharva007@prepration-evaluator-cl.59zqj5t.mongodb.net/?appName=prepration-evaluator-clustor"

client = MongoClient(uri)

print(client.list_database_names())
# Out:
# ['gre-question-bank', 'admin', 'local']

# %%
list(questions_collection.find())
# Out:
# [{'_id': ObjectId('69b004d9f8d1094af2aa2491'),
#   'question': 'If 3x + 9 = 18, what is x?',
#   'options': ['1', '2', '3', '4'],
#   'correct_answer': '3',
#   'difficulty': 0.2,
#   'topic': 'Algebra',
#   'tags': ['linear equations']},
#  {'_id': ObjectId('69b004d9f8d1094af2aa2492'),
#   'question': 'What is the value of 5^2?',
#   'options': ['10', '20', '25', '30'],
#   'correct_answer': '25',
#   'difficulty': 0.1,
#   'topic': 'Arithmetic',
#   'tags': ['exponents']},
#  {'_id': ObjectId('69b004d9f8d1094af2aa2493'),
#   'question': "The synonym of 'Aberration' is:",
#   'options': ['Deviation', 'Normality', 'Harmony', 'Balance'],
#   'correct_answer': 'Deviation',
#   'difficulty': 0.5,
#   'topic': 'Vocabulary',
#   'tags': ['synonyms']},
#  {'_id': ObjectId('69b004d9f8d1094af2aa2494'),
#   'question': 'If a triangle has sides 3,4,5 then it is:',
#   'options': ['Equilateral', 'Isosceles', 'Right triangle', 'Obtuse triangle'],
#   'correct_answer': 'Right triangle',
# ...
